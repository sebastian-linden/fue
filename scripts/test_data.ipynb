# %%
from fue import Data

data = Data()

# %%
data.read_raw()

# %%
data.raw
# Out:
#      location_name  latitude  longitude       forecasted_on  \
# 0           london   51.5074    -0.1278 2026-06-02 12:00:00
# 1           london   51.5074    -0.1278 2026-06-02 12:00:00
# 2           london   51.5074    -0.1278 2026-06-02 12:00:00
# 3           london   51.5074    -0.1278 2026-06-02 12:00:00
# 4           london   51.5074    -0.1278 2026-06-02 12:00:00
# ...            ...       ...        ...                 ...
# 9700     stockholm   59.2500    18.0000 2026-07-02 15:49:21
# 9701     stockholm   59.2500    18.0000 2026-07-02 15:49:21
# 9702     stockholm   59.2500    18.0000 2026-07-02 15:49:21
# 9703     stockholm   59.2500    18.0000 2026-07-02 15:49:21
# 9704     stockholm   59.2500    18.0000 2026-07-02 15:49:21
#
#             forecast_for  temperature_2m_max  temperature_2m_min  \
# 0    2026-06-02 23:59:59             20.8410             15.0410
# 1    2026-06-03 23:59:59             17.8410             14.1410
# ...

# %%
cities = ["aachen", "london", "stockholm"]
df = data.raw[data.raw["location_name"].isin(cities)]
df.to_csv("../tests/test_forecasts.csv", index=False)
